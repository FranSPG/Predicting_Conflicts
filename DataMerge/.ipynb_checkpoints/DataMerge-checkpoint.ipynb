# %%
import sys
sys.path.insert(0, 'C:/Users/Franco/Documents/AnacondaProjects/Predicting_Conflicts')
from Libs import *
from sklearn import preprocessing

#########

# Intersection_DF no devuelvo nada.. No se si sirve esto.

# %%
conflict_df = pd.read_csv('C:/Users/Franco/Documents/AnacondaProjects/Predicting_Conflicts/DataCleaning/ConflictDB/df_conflicto.csv', index_col=0)

programs_df = pd.read_csv('C:/Users/Franco/Documents/AnacondaProjects/Predicting_Conflicts/DataCleaning/ForeignAssProgDB/df_total.csv', index_col=0)

trade_df =  pd.read_csv('C:/Users/Franco/Documents/AnacondaProjects/Predicting_Conflicts/DataCleaning/TradeDB/TradeClean.csv', index_col=0)

conflict_df.rename(columns= {'location':'country'}, inplace=True)
trade_df.rename(columns= {'Recipient':'country', 'Year Weapon of order': 'year'}, inplace=True)
conflict_df.drop_duplicates(inplace=True)

# %%
df_part1 = pd.merge(conflict_df, programs_df, on=['country', 'year'], how='outer', left_index=False, right_index=False)
df_part2 = pd.merge(df_part1, trade_df, on=['country', 'year'], how='outer', left_index=False, right_index=False)

df_final = pd.merge(df_part1, df_part2, on=['country', 'year', 'amount'], how='outer', left_index=False, right_index=False)
df_final = df_final.drop_duplicates()
df_final['conflict'] = np.nan

# %%
df_final.drop(df_final[df_final['country'] == 'Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Africa and Europe Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'African Union'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Arabian Peninsula Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Asia Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Asia and Near East Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'CENTCOM Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Caribbean Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Central Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Central African Republic'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Central America Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Central Asia Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Central and Eastern Europe Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'EUCOM Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'East Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'East Asia and Pacific Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'East and Southern Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Eastern Caribbean Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Eurasia Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Europe Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Europe and Eurasia Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'FYR'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Global'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Great Lakes Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Lake Chad Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Latin America Region'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Levant Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Latin America Region'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Middle East and North Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Palestinian Territories'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Panama Canal Area Military School'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'South Asia Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'South Caucasus Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'South and Central Asia Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Southeast Asia Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Southern Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Southern Cone Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Southwest Asia Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Sub-Saharan Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'UAE'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'UN Transitional Administration in East Timor'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Unknown recipient(s)'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'West Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'West and North Africa Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Western Hemisphere Regional'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'Western Sahara'].index.tolist(), inplace=True)
df_final.drop(df_final[df_final['country'] == 'West and North Africa Regional'].index.tolist(), inplace=True)

# %%
df_final['country'] = df_final['country'].str.strip().str.replace('United States of America', 'United States').str.replace('Zimbabwe \(Rhodesia\)', 'Zimbabwe').str.replace('Yemen \(North Yemen\)', 'Yemen').str.replace('Viet Nam', 'Vietnam').str.replace('Vietnam \(North Vietnam\)', 'Vietnam').str.replace('The Gambia', 'Gambia').str.replace('Soviet Union', 'Russia').str.replace('South Vietnam', 'Vietnam').str.replace('South Yemen', 'Yemen').str.replace('South Sudan', 'Sudan').str.replace('St. Vincent and the Grenadines', 'Saint Vincent').str.replace('St. Kitts and Nevis', 'Saint Kitts and Nevis').str.replace('Rumania', 'Romania').str.replace('Northern Cyprus', 'Cyprus').str.replace('North Yemen', 'Yemen').str.replace('Madagascar \(Malagasy\)', 'Madagascar').str.replace('Macedonia \(FYROM\)', 'Macedonia').str.replace('Libya GNC', 'Libya').str.replace('Libya HoR', 'Libya').str.replace('Ivory Coast', "Cote d'Ivoire").str.replace('Germany \(FRG\)', 'Germany').str.replace('East Germany \(GDR\)', 'Germany').str.replace('DR Congo \(Zaire\)', 'Congo').str.replace('DR Congo', 'Congo').str.replace('Bosnia-Herzegovina', 'Bosnia and Herzegovina').str.replace('Yemen \(Yemen\)', 'Yemen').str.replace('Congo \(Zaire\)', 'Congo')

# %%
country_conflicto = conflict_df['country'].unique()

# %%
country_conflicto
# Out:
# array(['Bolivia', 'Cambodia', 'China', 'Greece', 'Indonesia', 'Iran',
#        'Israel', 'Laos', 'Philippines', 'Russia', 'France', 'Thailand',
#        'Albania', 'United Kingdom', 'Vietnam (North Vietnam)', 'India',
#        'Pakistan', 'Madagascar (Malagasy)', 'Paraguay', 'Myanmar',
#        'Costa Rica', 'Hyderabad', 'Egypt', 'Iraq', 'Jordan', 'Lebanon',
#        'Syria', 'Malaysia', 'Yemen (North Yemen)', 'Taiwan', 'Guatemala',
#        'North Korea', 'South Korea', 'United States of America', 'Kenya',
#        'Cuba', 'Morocco', 'Tunisia', 'Algeria', 'Argentina', 'Cyprus',
#        'South Vietnam', 'Hungary', 'Cameroon', 'Honduras', 'Nicaragua',
#        'Mauritania', 'Oman', 'Angola', 'DR Congo (Zaire)', 'Ethiopia',
#        'Somalia', 'Nepal', 'Brunei', 'Netherlands', 'Venezuela',
#        'Guinea-Bissau', 'Sudan', 'Gabon', 'Mozambique', 'South Yemen',
#        'Burundi', 'Chad', 'Colombia', 'Dominican Republic', 'Peru',
#        'Ghana', 'Nigeria', 'South Africa', 'El Salvador', 'Guinea',
#        'Sri Lanka', 'Uganda', 'Zimbabwe (Rhodesia)', 'Uruguay', 'Chile',
#        'Bangladesh', 'Turkey', 'Eritrea', 'Afghanistan', 'Saudi Arabia',
#        'Liberia', 'Spain', 'Gambia', 'Grenada', 'Burkina Faso', 'Mali',
#        'Suriname', 'Togo', 'Libya', 'Comoros', 'Panama',
#        'Papua New Guinea', 'Rumania', 'Kuwait', 'Niger', 'Rwanda',
#        'Senegal', 'Trinidad and Tobago', 'Djibouti', 'Georgia', 'Haiti',
#        'Sierra Leone', 'Serbia', 'Azerbaijan', 'Bosnia-Herzegovina',
#        'Croatia', 'Moldova', 'Tajikistan', 'Mexico', 'Ecuador', 'Congo',
#        'Lesotho', 'Uzbekistan', 'Central African Republic', 'Macedonia',
#        'FYR', 'Ivory Coast', 'Australia', 'Tanzania', 'South Sudan',
#        'Ukraine'], dtype=object)

# %%
for x in country_conflicto:
    year = conflict_df[conflict_df['country'] == x]['year']
    for i in year:
        df_final.loc[(df_final['country'] == x) & (df_final['year'] == i), 'conflict'] = True

# %%
df_final['Tools'].fillna(0, inplace=True)
df_final['Vehicles'].fillna(0, inplace=True)
df_final['Weapons'].fillna(0, inplace=True)

# %%
country_df_final = df_final['country'].unique()

# %%
df_final['conflict-1-to-3'] = np.nan
df_final['conflict-4-to-6'] = np.nan
df_final['conflict-7-to-9'] = np.nan
df_final['Prom USA'] = np.nan

# %%
for c in country_df_final:
    for x in range(1940, 2018):
        
        yearw_3 = 0
        yearw_2 = 0
        yearw_1 = 0
        prom_w = 0

        yearv_3 = 0
        yearv_2 = 0
        yearv_1 = 0
        prom_v = 0

        yeart_3 = 0
        yeart_2 = 0
        yeart_1 = 0
        prom_t = 0

        yearp_3 = 0
        yearp_2 = 0
        yearp_1 = 0
        prom_p = 0

        # weapons
        try:
            yearw_3 = df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['Weapons'].item()
        except:
            yearw_3 = 0
        try:
            yearw_2 = df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['Weapons'].item()
        except:
            yearw_2 = 0
        try:
            yearw_1 = df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['Weapons'].item()
        except:
            yearw_1 = 0

        prom_w = (yearw_3 + yearw_2 + yearw_1) / 3

        # Vehicles
        try:
            yearv_3 = df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['Vehicles'].item()
        except:
            yearv_3 = 0

        try:
            yearv_2 = df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['Vehicles'].item()
        except:
            yearv_2 = 0

        try:
            yearv_1 = df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['Vehicles'].item()
        except:
            yearv_1 = 0

        prom_v = (yearv_3 + yearv_2 + yearv_1) / 3

        # Tools
        try:
            yeart_3 = df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['Tools'].item()
        except:
            yeart_3 = 0

        try:
            yeart_2 = df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['Tools'].item()
        except:
            yeart_2 = 0

        try:
            yeart_1 = df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['Tools'].item()
        except:
            yeart_1 = 0


        prom_t = (yeart_3 + yeart_2 + yeart_1) / 3
        
        # PROM USA
        try:
            yearp_3 = df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['amount'].item()
        except:
            yearp_3 = 0

        try:
            yearp_2 = df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['amount'].item()
        except:
            yearp_2 = 0

        try:
            yearp_1 = df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['amount'].item()
        except:
            yearp_1 = 0

        prom_p = (yearp_3 + yearp_2 + yearp_1) / 3
            
        df_final.loc[(df_final['year'] == x) & (df_final['country'] == c), 'Prom Tools'] = prom_t
        df_final.loc[(df_final['year'] == x) & (df_final['country'] == c), 'Prom Vehicles'] = prom_v
        df_final.loc[(df_final['year'] == x) & (df_final['country'] == c), 'Prom Weapons'] = prom_w
        df_final.loc[(df_final['year'] == x) & (df_final['country'] == c), 'Prom USA'] = prom_p

# %%
for c in country_df_final:
    for x in range(1940, 2019):  


            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-1-to-3'] = True
                    #df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-5'] = True
                    #df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-10'] = True
            except:
                pass

            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-1-to-3'] = True
                    #df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-5'] = True
                    #df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-10'] = True
            except:
                pass

            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-1-to-3'] = True
                    #df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-5'] = True
                    #df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-10'] = True
            except:
                pass

            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-4)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-4-to-6'] = True
                    #df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-10'] = True
            except:
                pass

            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-5)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-4-to-6'] = True
                    #df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-10'] = True
            except:
                pass

            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-6)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-4-to-6'] = True
            except:
                pass
            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-7)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-7-to-9'] = True
            except:
                pass
            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-8)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-7-to-9'] = True
            except:
                pass
            try:
                if(df_final[(df_final['country'] == c) & (df_final['year'] == x-9)]['conflict'].item()):
                    df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-7-to-9'] = True
            except:
                pass
            #try:
                #    if(df_final[(df_final['country'] == c) & (df_final['year'] == x-10)]['conflict'].item()):
                #        df_final.loc[(df_final['country'] == c) & (df_final['year'] == x), 'conflict-10'] = True
            #except:
                #    pass

# %%
for x in range(1940, 2019):
    for c in df_final['country'].unique():
        
        yearp_3 = 0
        yearp_2 = 0
        yearp_1 = 0
        prom_p = 0
            
        
            # PROM USA
        try:
            if(df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['amount'].isnull().item()):
                yearp_3 = 0
            else:    
                yearp_3 = df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['amount'].item()
        except:
            yearp_3 = 0

        try:
            if(df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['amount'].isnull().item()):
                yearp_2 = 0
            else:
                yearp_2 = df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['amount'].item()
        except:
            yearp_2 = 0

        try:
            if(df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['amount'].isnull().item()):
                yearp_1 = 0
            else:
                yearp_1 = df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['amount'].item()
        except:
            yearp_1 = 0

        prom_p = (yearp_3 + yearp_2 + yearp_1) / 3
        
        
        df_final.loc[(df_final['year'] == x) & (df_final['country'] == c), 'Prom USA'] = prom_p
        #print("Year: {}, yearp_3: {}, yearp_2: {}, yearp_1: {}, prom_p: {}".format(x, yearp_3, yearp_2, yearp_1, prom_p))

# %%
x = 2018
for c in df_final['country'].unique():
        
        yearw_3 = 0
        yearw_2 = 0
        yearw_1 = 0
        prom_w = 0

        yearv_3 = 0
        yearv_2 = 0
        yearv_1 = 0
        prom_v = 0

        yeart_3 = 0
        yeart_2 = 0
        yeart_1 = 0
        prom_t = 0


        # weapons
        try:
            yearw_3 = df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['Weapons'].item()
        except:
            yearw_3 = 0
        try:
            yearw_2 = df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['Weapons'].item()
        except:
            yearw_2 = 0
        try:
            yearw_1 = df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['Weapons'].item()
        except:
            yearw_1 = 0

        prom_w = (yearw_3 + yearw_2 + yearw_1) / 3

        # Vehicles
        try:
            yearv_3 = df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['Vehicles'].item()
        except:
            yearv_3 = 0

        try:
            yearv_2 = df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['Vehicles'].item()
        except:
            yearv_2 = 0

        try:
            yearv_1 = df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['Vehicles'].item()
        except:
            yearv_1 = 0

        prom_v = (yearv_3 + yearv_2 + yearv_1) / 3

        # Tools
        try:
            yeart_3 = df_final[(df_final['country'] == c) & (df_final['year'] == x-3)]['Tools'].item()
        except:
            yeart_3 = 0

        try:
            yeart_2 = df_final[(df_final['country'] == c) & (df_final['year'] == x-2)]['Tools'].item()
        except:
            yeart_2 = 0

        try:
            yeart_1 = df_final[(df_final['country'] == c) & (df_final['year'] == x-1)]['Tools'].item()
        except:
            yeart_1 = 0


        prom_t = (yeart_3 + yeart_2 + yeart_1) / 3
            
        df_final.loc[(df_final['year'] == x) & (df_final['country'] == c), 'Prom Tools'] = prom_t
        df_final.loc[(df_final['year'] == x) & (df_final['country'] == c), 'Prom Vehicles'] = prom_v
        df_final.loc[(df_final['year'] == x) & (df_final['country'] == c), 'Prom Weapons'] = prom_w

# %%
df_final.drop(list(df_final.loc[(df_final['Tools'] == 0) & (df_final['Vehicles'] == 0) & (df_final['Weapons'] == 0) & (df_final['Prom Tools'] == 0) & (df_final['Prom Vehicles'] == 0) & (df_final['Prom Weapons'] == 0) & (df_final['conflict'] == False) & (df_final['conflict-1-to-3'] == False) & (df_final['conflict-4-to-6'] == False) & (df_final['conflict-7-to-9'] == False), :].index), inplace=True)

# %%
df_final.head()
# Out:
#    year   country  amount  Tools  Vehicles  Weapons  Prom Tools  \
# 0  1946   Bolivia     nan    nan       nan      nan        0.00
# 1  1952   Bolivia     nan    nan       nan      nan        0.00
# 2  1967   Bolivia     nan    nan     53.00    24.00         nan
# 3  1946  Cambodia     nan    nan       nan      nan        0.00
# 4  1947  Cambodia     nan    nan       nan      nan         nan
#
#    Prom Vehicles  Prom Weapons conflict conflict-1-to-3 conflict-4-to-6  \
# 0           0.00          0.00     True             NaN             NaN
# 1           0.00          0.00     True             NaN            True
# 2           9.33           nan     True            True            True
# 3           0.00          0.00     True             NaN             NaN
# 4            nan           nan     True            True             NaN
#
#   conflict-7-to-9  Prom USA
# 0             NaN      0.00
# 1             NaN      0.00
# 2            True      0.00
# 3             NaN      0.00
# 4             NaN      0.00

# %%
encoder = preprocessing.LabelEncoder()
encoder.fit(df_final['country'].unique())
# Out:
# LabelEncoder()

# %%
countries_total = df_final['country']
countries_total_encoded = encoder.transform(countries_total)

# %%
len(countries_total_encoded)
# Out:
# 8578

# %%
df_final['country encoded'] = countries_total_encoded

# %%
df_final
# Out:
#       year              country        amount   Tools  Vehicles  Weapons  \
# 0     1946              Bolivia           nan     nan       nan      nan
# 1     1952              Bolivia           nan     nan       nan      nan
# 2     1967              Bolivia           nan     nan     53.00    24.00
# 3     1946             Cambodia           nan     nan       nan      nan
# 4     1947             Cambodia           nan     nan       nan      nan
# 5     1948             Cambodia           nan     nan       nan      nan
# 6     1949             Cambodia           nan     nan       nan      nan
# 7     1950             Cambodia           nan     nan       nan      nan
# 8     1951             Cambodia           nan     nan       nan      nan
# 9     1952             Cambodia           nan     nan       nan      nan
# 10    1953             Cambodia           nan     nan     15.00      nan
# 11    1946                China           nan     nan       nan      nan
# 12    1947                China           nan     nan       nan      nan
# 13    1948                China           nan     nan       nan      nan
# 14    1949                China           nan     nan   5200.00  3000.00
# 15    1946               Greece           nan     nan       nan      nan
# 16    1947               Greece           nan     nan       nan      nan
# 17    1948               Greece           nan     nan       nan      nan
# 18    1949               Greece           nan     nan    105.00   587.00
# 19    1946            Indonesia           nan     nan       nan      nan
# 20    1947            Indonesia           nan     nan       nan      nan
# 21    1948            Indonesia           nan     nan      9.00      nan
# 22    1949            Indonesia           nan     nan      7.00      nan
# 23    1946                 Iran           nan     nan       nan      nan
# 8837            True            True          0.00              201
# 8838            True            True          0.00              201
# 8839            True            True          0.00              201
# 8840            True            True          0.00              201
# 8841            True            True          0.00              201
# 8842            True            True          0.00              201
# 8843            True            True          0.00              201
# 8844            True            True          0.00              201
# 8845            True            True          0.00              201
# 8846            True            True          0.00              201
# 8847            True            True          0.00              201
# 8848            True            True          0.00              201
# 8849            True            True          0.00              201
# 8850            True            True          0.00              201
# 8851            True            True          0.00              201
# 8852            True            True          0.00              201
# 8853            True            True          0.00              201
# 8854            True            True          0.00              201
# 8855            True            True          0.00              201
# 8856            True            True          0.00              201
# 8857            True            True          0.00              201
# 8858            True            True          0.00              201
# 8859            True            True          0.00              201
# 8860            True            True          0.00              201
# 8861            True            True          0.00              201
# 8862             NaN             NaN          0.00              203
# 8863             NaN             NaN          0.00              204
# 8864             NaN             NaN          0.00              204
# 8865             NaN             NaN          0.00              204
# 8866             NaN             NaN          0.00              204
# 8867            True             NaN          0.00              204
# 8868            True             NaN          0.00              204
# 8869            True             NaN          0.00              204
# 8870            True            True          0.00              204
# 8871            True            True          0.00              204
# 8872            True            True          0.00              204
# 8873            True            True          0.00              204
# 8874            True            True          0.00              204
# 8875            True            True          0.00              204
# 8876            True            True          0.00              204
# 8877            True            True          0.00              204
# 8878            True            True          0.00              204
# 8879            True            True          0.00              204
# 8880            True            True          0.00              204
# 8881            True            True          0.00              204
# 8882            True            True          0.00              204
# 8883            True            True          0.00              204
# 8884            True            True          0.00              204
# 8885            True            True          0.00              204
# 8886            True            True          0.00              204
# 8887            True            True          0.00              204
# 8888            True            True          0.00              204
# 8889            True            True          0.00              204
# 8890            True            True          0.00              204
# 8891            True            True          0.00              204
# 8892            True            True          0.00              204
# 8893            True            True          0.00              204
# 8894            True            True          0.00              204
# 8895            True            True          0.00              204
# 8896            True            True          0.00              204
# 8897            True            True          0.00              204
# 8898            True            True          0.00              204
# 8899            True            True          0.00              204
# 8900            True            True          0.00              204
# 8901            True            True          0.00              204
# 8902            True            True          0.00              204
# 8903            True            True          0.00              204
# 8904            True            True          0.00              204
# 8905            True            True          0.00              205
# 8906            True            True          0.00              205
# 8907            True            True          0.00              205
# 8908             NaN            True          0.00              205
# 8909            True             NaN          0.00              205
# 8910            True             NaN          0.00              205
# 8911            True            True          0.00              205
# 8912            True            True          0.00              205
# 8913            True            True          0.00              205
# 8914            True            True          0.00              205
# 8915             NaN            True          0.00              205
# 8916             NaN            True          0.00              205
# 8917             NaN            True          0.00              205
# 8918             NaN             NaN          0.00              205
# 8919             NaN             NaN          0.00              205
# 8920             NaN             NaN          0.00              205
# 8921             NaN             NaN          0.00              205
# 8922             NaN             NaN          0.00              205
# 8923             NaN             NaN          0.00              205
# 8924             NaN             NaN          0.00              205
# 8925             NaN             NaN          0.00              205
# 8926             NaN             NaN          0.00              205
# 8927             NaN             NaN          0.00              205
# 8928            True             NaN          0.00              205
# 8929            True             NaN          0.00              205
# 8930            True             NaN          0.00              205
# 8931             NaN            True          0.00              205
# 8932             NaN            True          0.00              205
# 8933             NaN            True          0.00              205
# 8934            True             NaN          0.00              205
# 8935            True             NaN          0.00              205
# 8936            True             NaN          0.00              205
# 8937            True            True          0.00              205
# 8938            True            True          0.00              205
# 8939            True             NaN          0.00              205
# 8940             NaN            True          0.00              205
# 8941             NaN            True          0.00              205
# 8942            True            True          0.00              205
# 8943            True             NaN          0.00              205
# 8944            True            True     346912.00              205
# 8945            True            True     346912.00              205
# 8946            True            True     346912.00              205
# 8947            True            True          0.00              205
# 8948            True            True    1127000.00              205
# 8949             NaN            True    1127000.00              205
# 8950             NaN            True    1127000.00              205
# 8951            True            True          0.00              205
# 8952            True             NaN          0.00              205
# 8953            True             NaN          0.00              205
# 8954             NaN            True          0.00              205
# 8955             NaN            True          0.00              205
# 8956             NaN            True          0.00              205
# 8957             NaN             NaN          0.00              205
# 8958             NaN             NaN          0.00              205
# 8959             NaN             NaN          0.00              205
# 8969            True             NaN          0.00              206
# 8970            True             NaN          0.00              206
# 8971            True            True          0.00              206
# 8972            True            True          0.00              206
# 8973            True            True          0.00              206
# 8974             NaN            True          0.00              206
# 8975             NaN             NaN          0.00              207
# 8976             NaN             NaN          0.00              207
# 8977             NaN             NaN          0.00              207
# 8978             NaN             NaN          0.00              207
# 8979            True             NaN          0.00              207
# 8980            True             NaN          0.00              207
# 8981            True             NaN          0.00              207
# 8982            True            True          0.00              207
# 8983            True            True          0.00              207
# 8984            True            True          0.00              207
# 8985            True            True          0.00              207
# 8986            True            True          0.00              207
# 8987            True            True          0.00              207
# 8988            True            True          0.00              207
# 8989            True            True          0.00              207
# 8990            True            True          0.00              207
# 8991            True            True          0.00              207
# 8992            True            True          0.00              207
# 8993            True            True          0.00              207
# 8994            True            True          0.00              207
# 8995            True            True          0.00              207
# 8996            True            True          0.00              207
# 8997            True            True          0.00              207
# 8998            True            True          0.00              207
# 8999            True            True          0.00              207
# 9000            True            True          0.00              207
# 9001            True            True          0.00              207
# 9002            True            True          0.00              207
# 9003            True            True          0.00              207
# 9004            True            True          0.00              207
# 9005            True            True          0.00              207
# 9006            True            True          0.00              207
# 9007            True            True          0.00              207
# 9008            True            True          0.00              207
# 9009            True            True          0.00              207
# 9010            True            True          0.00              207
# 9011            True            True          0.00              207
# 9012             NaN             NaN          0.00              208
# 9013             NaN             NaN          0.00              208
# 9014             NaN             NaN          0.00              208
# 9015             NaN             NaN          0.00              208
# 9016            True             NaN          0.00              208
# 9017            True            True          0.00              208
# 9018            True            True          0.00              208
# 9019            True            True          0.00              208
# 9020            True            True          0.00              208
# 9021            True            True          0.00              208
# 9022            True            True          0.00              208
# 9023            True            True          0.00              208
# 9024            True            True          0.00              208
# 9025            True            True          0.00              208
# 9026            True            True          0.00              208
# 9027            True            True          0.00              208
# 9028            True            True          0.00              208
# 9029             NaN             NaN          0.00              208
# 9030            True             NaN          0.00              208
#
# [8578 rows x 15 columns]

# %%
df_final.to_csv('df_final.csv')
